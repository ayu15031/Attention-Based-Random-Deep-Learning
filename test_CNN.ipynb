# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Github/ARDL
# Out:
# /content/drive/MyDrive/Github/ARDL

# %%
# %load_ext autoreload
# %autoreload 2

from dataset import *
from torch.utils.data import TensorDataset, DataLoader

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from sklearn.datasets import fetch_20newsgroups

newsgroups_train = fetch_20newsgroups(subset='train', categories=categories)
newsgroups_test = fetch_20newsgroups(subset='test', categories=categories)

# %%
emb_mat, data = create_inp_data_and_weights(newsgroups_train, newsgroups_test, glove_dim=50)
# Out:
# Vocabulary size [Bag-of-words]:  151353
# Vocabulary size [GloVe]:  400000

# %%
from cnn import *
input_size, emb_size = emb_mat.shape

model = build_random_cnn(3, 5, 128, 256, input_size, emb_size, 7, emb_mat)
model
# Out:
# CNN(
#   (embedding): Embedding(151353, 50)
#   (conv_layers): Sequential(
#     (0): Conv1d(50, 215, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): ReLU()
#     (2): BatchNorm1d(215, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv1d(215, 153, kernel_size=(5,), stride=(1,), padding=(2,))
#     (6): ReLU()
#     (7): BatchNorm1d(153, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): Dropout(p=0.5, inplace=False)
#     (9): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv1d(153, 141, kernel_size=(5,), stride=(1,), padding=(2,))
#     (11): ReLU()
#     (12): BatchNorm1d(141, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): Dropout(p=0.5, inplace=False)
#     (14): MaxPool1d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv1d(141, 147, kernel_size=(5,), stride=(1,), padding=(2,))
#     (16): ReLU()
#     (17): BatchNorm1d(147, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): Dropout(p=0.5, inplace=False)
#     (19): AdaptiveMaxPool1d(output_size=20)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=2940, out_features=256, bias=True)
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=256, out_features=7, bias=True)
#   (bn2): BatchNorm1d(7, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (att): Linear(in_features=256, out_features=7, bias=True)
# )

# %%
# learning_rate = 0.001
# num_epochs = 10
# batch_size = 512
# display_step = 4
learning_rate = 0.001
num_epochs = 17
batch_size = 128
display_step = 4

criterion = nn.CrossEntropyLoss()  
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
from torch.autograd import Variable

# %%
training_loss = []
validation_loss = []

total_batch = int(len(newsgroups_train.data)/batch_size)
    
total_batch_val = int(len(newsgroups_test.data)/batch_size)
model = model.to(device)
for epoch in range(num_epochs):
    tr_loss = []
    model.train()

    total_batch = int(len(newsgroups_train.data)/batch_size)
    # Loop over all batches
    for i in range(total_batch):
        batch_x,batch_y = get_batch(data['train'],i,batch_size)

        articles = Variable(torch.LongTensor(batch_x)).to(device)
        labels = Variable(torch.LongTensor(batch_y)).to(device)
        
        # Forward + Backward + Optimize
        optimizer.zero_grad()  # zero the gradient buffer
        _, outputs = model(articles)
        #print(outputs.shape, labels.shape)
        loss = criterion(outputs, labels)
        tr_loss.append(loss.data)
        loss.backward()
        optimizer.step()

    if (i+1) % display_step == 0:
        print ('Epoch [%d/%d], Step [%d/%d], Loss: %.4f'
                %(epoch+1, num_epochs, i+1, len(newsgroups_train.data)//batch_size, sum(tr_loss)/total_batch))    
    
    model.eval()
    training_loss.append(sum(tr_loss)/total_batch)

    model.eval()
    # Loop over all batches
    batch_val_loss = []
    for i in range(total_batch_val):
        
        batch_x,batch_y = get_batch(data['test'],i,batch_size)

        articles = Variable(torch.LongTensor(batch_x)).to(device)
        labels = Variable(torch.LongTensor(batch_y)).to(device)

        _, y_test_pred = model(articles)
        
        test_loss = criterion(y_test_pred, labels)
        batch_val_loss.append(test_loss.data)

    if (i+1) % display_step == 0:
        print ('Epoch [%d/%d], Step [%d/%d], Val Loss: %.4f'
                %(epoch+1, num_epochs, i+1, len(newsgroups_train.data)//batch_size, sum(batch_val_loss)/total_batch_val))    

    validation_loss.append(sum(batch_val_loss)/total_batch_val)
# Out:
# /content/drive/MyDrive/Github/ARDL/cnn.py:54: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
# Epoch [1/10], Step [4/88], Loss: 1.8718
# Epoch [1/10], Step [8/88], Loss: 1.8169
# Epoch [1/10], Step [12/88], Loss: 1.6806
# Epoch [1/10], Step [16/88], Loss: 1.7847
# Epoch [1/10], Step [20/88], Loss: 1.7543
# Epoch [1/10], Step [24/88], Loss: 1.6975
# Epoch [1/10], Step [28/88], Loss: 1.5290
# Epoch [1/10], Step [32/88], Loss: 1.3659
# Epoch [1/10], Step [36/88], Loss: 1.4722
# Epoch [1/10], Step [40/88], Loss: 1.2322
# Epoch [1/10], Step [44/88], Loss: 1.3669
# Epoch [1/10], Step [48/88], Loss: 1.2823
# Epoch [1/10], Step [52/88], Loss: 1.3010
# Epoch [1/10], Step [56/88], Loss: 1.2115
# Epoch [1/10], Step [60/88], Loss: 1.2778
# Epoch [1/10], Step [64/88], Loss: 1.2004
# Epoch [1/10], Step [68/88], Loss: 1.3131
# Epoch [1/10], Step [72/88], Loss: 1.1071
# Epoch [1/10], Step [76/88], Loss: 1.1590
# Epoch [1/10], Step [80/88], Loss: 1.0603
# Epoch [1/10], Step [84/88], Loss: 1.2858
# Epoch [1/10], Step [88/88], Loss: 1.1237
# Epoch [2/10], Step [4/88], Loss: 1.1465
# Epoch [2/10], Step [8/88], Loss: 1.0354
# Epoch [2/10], Step [12/88], Loss: 1.0780
# Epoch [2/10], Step [16/88], Loss: 1.0202
# Epoch [2/10], Step [20/88], Loss: 0.9963
# Epoch [2/10], Step [24/88], Loss: 0.9046
# Epoch [2/10], Step [28/88], Loss: 0.8941
# Epoch [2/10], Step [32/88], Loss: 0.7756
# Epoch [2/10], Step [36/88], Loss: 0.9236
# Epoch [2/10], Step [40/88], Loss: 0.8575
# Epoch [2/10], Step [44/88], Loss: 1.0259
# Epoch [2/10], Step [48/88], Loss: 0.7102
# Epoch [2/10], Step [52/88], Loss: 0.7612
# Epoch [2/10], Step [56/88], Loss: 0.8106
# Epoch [2/10], Step [60/88], Loss: 0.8699
# Epoch [2/10], Step [64/88], Loss: 0.7797
# Epoch [2/10], Step [68/88], Loss: 0.8797
# Epoch [2/10], Step [72/88], Loss: 0.8214
# Epoch [2/10], Step [76/88], Loss: 0.7371
# Epoch [2/10], Step [80/88], Loss: 0.7099
# Epoch [2/10], Step [84/88], Loss: 0.8862
# Epoch [2/10], Step [88/88], Loss: 0.7559
# Epoch [3/10], Step [4/88], Loss: 0.7230
# Epoch [3/10], Step [8/88], Loss: 0.8592
# Epoch [3/10], Step [12/88], Loss: 0.8543
# Epoch [3/10], Step [16/88], Loss: 0.8199
# Epoch [3/10], Step [20/88], Loss: 0.8237
# Epoch [3/10], Step [24/88], Loss: 0.7499
# Epoch [3/10], Step [28/88], Loss: 0.7371
# Epoch [3/10], Step [32/88], Loss: 0.6699
# Epoch [3/10], Step [36/88], Loss: 0.7895
# Epoch [3/10], Step [40/88], Loss: 0.5764
# Epoch [3/10], Step [44/88], Loss: 0.9392
# Epoch [3/10], Step [48/88], Loss: 0.5511
# Epoch [3/10], Step [52/88], Loss: 0.5260
# Epoch [3/10], Step [56/88], Loss: 0.6732
# Epoch [3/10], Step [60/88], Loss: 0.6507
# Epoch [3/10], Step [64/88], Loss: 0.6402
# Epoch [3/10], Step [68/88], Loss: 0.7037
# Epoch [3/10], Step [72/88], Loss: 0.6092
# Epoch [3/10], Step [76/88], Loss: 0.6838
# Epoch [3/10], Step [80/88], Loss: 0.6658
# Epoch [3/10], Step [84/88], Loss: 0.6513
# Epoch [3/10], Step [88/88], Loss: 0.6446
# Epoch [4/10], Step [4/88], Loss: 0.7205
# Epoch [4/10], Step [8/88], Loss: 0.8018
# Epoch [4/10], Step [12/88], Loss: 0.6676
# Epoch [4/10], Step [16/88], Loss: 0.6819
# Epoch [4/10], Step [20/88], Loss: 0.6604
# Epoch [4/10], Step [24/88], Loss: 0.5639
# Epoch [4/10], Step [28/88], Loss: 0.6725
# Epoch [4/10], Step [32/88], Loss: 0.5963
# Epoch [4/10], Step [36/88], Loss: 0.6253
# Epoch [4/10], Step [40/88], Loss: 0.5428
# Epoch [4/10], Step [44/88], Loss: 0.7799
# Epoch [4/10], Step [48/88], Loss: 0.4596
# Epoch [4/10], Step [52/88], Loss: 0.4859
# Epoch [4/10], Step [56/88], Loss: 0.5633
# Epoch [4/10], Step [60/88], Loss: 0.5901
# Epoch [4/10], Step [64/88], Loss: 0.5929
# Epoch [4/10], Step [68/88], Loss: 0.6557
# Epoch [4/10], Step [72/88], Loss: 0.4778
# Epoch [4/10], Step [76/88], Loss: 0.5267
# Epoch [4/10], Step [80/88], Loss: 0.6292
# Epoch [4/10], Step [84/88], Loss: 0.6304
# Epoch [4/10], Step [88/88], Loss: 0.5259
# Epoch [5/10], Step [4/88], Loss: 0.6202
# Epoch [5/10], Step [8/88], Loss: 0.7008
# Epoch [5/10], Step [12/88], Loss: 0.6759
# Epoch [5/10], Step [16/88], Loss: 0.5191
# Epoch [5/10], Step [20/88], Loss: 0.5783
# Epoch [5/10], Step [24/88], Loss: 0.4697
# Epoch [5/10], Step [28/88], Loss: 0.5492
# Epoch [5/10], Step [32/88], Loss: 0.4640
# Epoch [5/10], Step [36/88], Loss: 0.5528
# Epoch [5/10], Step [40/88], Loss: 0.4737
# Epoch [5/10], Step [44/88], Loss: 0.6188
# Epoch [5/10], Step [48/88], Loss: 0.4756
# Epoch [5/10], Step [52/88], Loss: 0.4103
# Epoch [5/10], Step [56/88], Loss: 0.4915
# Epoch [5/10], Step [60/88], Loss: 0.4481
# Epoch [5/10], Step [64/88], Loss: 0.4996
# Epoch [5/10], Step [68/88], Loss: 0.5702
# Epoch [5/10], Step [72/88], Loss: 0.4585
# Epoch [5/10], Step [76/88], Loss: 0.5148
# Epoch [5/10], Step [80/88], Loss: 0.4784
# Epoch [5/10], Step [84/88], Loss: 0.5485
# Epoch [5/10], Step [88/88], Loss: 0.4748
# Epoch [6/10], Step [4/88], Loss: 0.6640
# Epoch [6/10], Step [8/88], Loss: 0.5620
# Epoch [6/10], Step [12/88], Loss: 0.5175
# Epoch [6/10], Step [16/88], Loss: 0.3979
# Epoch [6/10], Step [20/88], Loss: 0.5174
# Epoch [6/10], Step [24/88], Loss: 0.3791
# Epoch [6/10], Step [28/88], Loss: 0.5144
# Epoch [6/10], Step [32/88], Loss: 0.4229
# Epoch [6/10], Step [36/88], Loss: 0.5328
# Epoch [6/10], Step [40/88], Loss: 0.4627
# Epoch [6/10], Step [44/88], Loss: 0.5563
# Epoch [6/10], Step [48/88], Loss: 0.3720
# Epoch [6/10], Step [52/88], Loss: 0.3739
# Epoch [6/10], Step [56/88], Loss: 0.3831
# Epoch [6/10], Step [60/88], Loss: 0.4244
# Epoch [6/10], Step [64/88], Loss: 0.4385
# Epoch [6/10], Step [68/88], Loss: 0.5416
# Epoch [6/10], Step [72/88], Loss: 0.4399
# Epoch [6/10], Step [76/88], Loss: 0.4223
# Epoch [6/10], Step [80/88], Loss: 0.4816
# Epoch [6/10], Step [84/88], Loss: 0.5803
# Epoch [6/10], Step [88/88], Loss: 0.4528
# Epoch [7/10], Step [4/88], Loss: 0.5214
# Epoch [7/10], Step [8/88], Loss: 0.6382
# Epoch [7/10], Step [12/88], Loss: 0.5928
# Epoch [7/10], Step [16/88], Loss: 0.5184
# Epoch [7/10], Step [20/88], Loss: 0.4642
# Epoch [7/10], Step [24/88], Loss: 0.3560
# Epoch [7/10], Step [28/88], Loss: 0.5132
# Epoch [7/10], Step [32/88], Loss: 0.4132
# Epoch [7/10], Step [36/88], Loss: 0.4224
# Epoch [7/10], Step [40/88], Loss: 0.4384
# Epoch [7/10], Step [44/88], Loss: 0.5546
# Epoch [7/10], Step [48/88], Loss: 0.2826
# Epoch [7/10], Step [52/88], Loss: 0.3105
# Epoch [7/10], Step [56/88], Loss: 0.3913
# Epoch [7/10], Step [60/88], Loss: 0.4194
# Epoch [7/10], Step [64/88], Loss: 0.5321
# Epoch [7/10], Step [68/88], Loss: 0.6649
# Epoch [7/10], Step [72/88], Loss: 0.4570
# Epoch [7/10], Step [76/88], Loss: 0.4623
# Epoch [7/10], Step [80/88], Loss: 0.4408
# Epoch [7/10], Step [84/88], Loss: 0.3970
# Epoch [7/10], Step [88/88], Loss: 0.5047
# Epoch [8/10], Step [4/88], Loss: 0.5510
# Epoch [8/10], Step [8/88], Loss: 0.4547
# Epoch [8/10], Step [12/88], Loss: 0.4267
# Epoch [8/10], Step [16/88], Loss: 0.3492
# Epoch [8/10], Step [20/88], Loss: 0.4010
# Epoch [8/10], Step [24/88], Loss: 0.3528
# Epoch [8/10], Step [28/88], Loss: 0.4710
# Epoch [8/10], Step [32/88], Loss: 0.2982
# Epoch [8/10], Step [36/88], Loss: 0.4678
# Epoch [8/10], Step [40/88], Loss: 0.4351
# Epoch [8/10], Step [44/88], Loss: 0.4672
# Epoch [8/10], Step [48/88], Loss: 0.3014
# Epoch [8/10], Step [52/88], Loss: 0.3039
# Epoch [8/10], Step [56/88], Loss: 0.3477
# Epoch [8/10], Step [60/88], Loss: 0.2902
# Epoch [8/10], Step [64/88], Loss: 0.4199
# Epoch [8/10], Step [68/88], Loss: 0.4896
# Epoch [8/10], Step [72/88], Loss: 0.3329
# Epoch [8/10], Step [76/88], Loss: 0.3296
# Epoch [8/10], Step [80/88], Loss: 0.3236
# Epoch [8/10], Step [84/88], Loss: 0.4468
# Epoch [8/10], Step [88/88], Loss: 0.3945
# Epoch [9/10], Step [4/88], Loss: 0.4595
# Epoch [9/10], Step [8/88], Loss: 0.4699
# Epoch [9/10], Step [12/88], Loss: 0.3448
# Epoch [9/10], Step [16/88], Loss: 0.3054
# Epoch [9/10], Step [20/88], Loss: 0.3569
# Epoch [9/10], Step [24/88], Loss: 0.3263
# Epoch [9/10], Step [28/88], Loss: 0.3568
# Epoch [9/10], Step [32/88], Loss: 0.2510
# Epoch [9/10], Step [36/88], Loss: 0.3596
# Epoch [9/10], Step [40/88], Loss: 0.3106
# Epoch [9/10], Step [44/88], Loss: 0.5326
# Epoch [9/10], Step [48/88], Loss: 0.2326
# Epoch [9/10], Step [52/88], Loss: 0.3115
# Epoch [9/10], Step [56/88], Loss: 0.3350
# Epoch [9/10], Step [60/88], Loss: 0.2757
# Epoch [9/10], Step [64/88], Loss: 0.3146
# Epoch [9/10], Step [68/88], Loss: 0.4012
# Epoch [9/10], Step [72/88], Loss: 0.2670
# Epoch [9/10], Step [76/88], Loss: 0.2996
# Epoch [9/10], Step [80/88], Loss: 0.3484
# Epoch [9/10], Step [84/88], Loss: 0.3732
# Epoch [9/10], Step [88/88], Loss: 0.3378
# Epoch [10/10], Step [4/88], Loss: 0.4103
# Epoch [10/10], Step [8/88], Loss: 0.3534
# Epoch [10/10], Step [12/88], Loss: 0.3123
# Epoch [10/10], Step [16/88], Loss: 0.2634
# Epoch [10/10], Step [20/88], Loss: 0.4021
# Epoch [10/10], Step [24/88], Loss: 0.2960
# Epoch [10/10], Step [28/88], Loss: 0.3348
# Epoch [10/10], Step [32/88], Loss: 0.2984
# Epoch [10/10], Step [36/88], Loss: 0.2886
# Epoch [10/10], Step [40/88], Loss: 0.3026
# Epoch [10/10], Step [44/88], Loss: 0.4580
# Epoch [10/10], Step [48/88], Loss: 0.2084
# Epoch [10/10], Step [52/88], Loss: 0.2446
# Epoch [10/10], Step [56/88], Loss: 0.2676
# Epoch [10/10], Step [60/88], Loss: 0.2934
# Epoch [10/10], Step [64/88], Loss: 0.3791
# Epoch [10/10], Step [68/88], Loss: 0.3312
# Epoch [10/10], Step [72/88], Loss: 0.2574
# Epoch [10/10], Step [76/88], Loss: 0.3200
# Epoch [10/10], Step [80/88], Loss: 0.3537
# Epoch [10/10], Step [84/88], Loss: 0.3437
# Epoch [10/10], Step [88/88], Loss: 0.3302

# %%
folder_name = 'models/cnn/model_2_11_03/'

from matplotlib import pyplot as plt
# training_loss = np.array(training_loss)
# validation_loss = np.array(validation_loss)

for i in range(len(training_loss)):
  training_loss[i] = training_loss[i].cpu()

for i in range(len(validation_loss)):
  validation_loss[i] = validation_loss[i].cpu()


training_loss_ = np.array(training_loss)
validation_loss_ = np.array(validation_loss)


fig = plt.figure()
plt.plot(training_loss_)
plt.plot(validation_loss_)
plt.legend(["Training Loss", "Validation Loss"])
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.show()
fig.savefig(folder_name + 'loss_vs_epoch.png')

# %%
total_batch = int(len(newsgroups_test.data)/batch_size)
correct = 0
total = 0
# Loop over all batches
for i in range(total_batch):
    batch_x,batch_y = get_batch(data['test'],i,batch_size)

    articles = Variable(torch.LongTensor(batch_x)).to(device)
    labels = Variable(torch.LongTensor(batch_y)).to(device)

    # Final validation accuracy
    total, correct = 0, 0
    model.eval()
    _, y_test_pred = model(articles)
    predicted = torch.argmax(y_test_pred, 1)

    total += y_test_pred.size(0)

    correct += (predicted == labels).sum()

print(f'Accuracy of the model is: {100*correct/total:.2f}%')
# Out:
# /content/drive/MyDrive/Github/ARDL/cnn.py:60: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return a, F.log_softmax(y)
# Accuracy of the model is: 75.78%

# %%
# Additional information
PATH = folder_name + "model.pt"
LOSS = 0.3302
ACCURACY = 75.78

# Store model
torch.save({
            'accuracy': ACCURACY,
            'epoch': num_epochs,
            'learning_rate': learning_rate,
            'batch_size': batch_size,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': LOSS,
            }, PATH)

# Store model architecture
import pickle
file_name = folder_name + 'model_architecture.pickle'
with open(file_name, 'wb') as f:
    pickle.dump(model, f)
